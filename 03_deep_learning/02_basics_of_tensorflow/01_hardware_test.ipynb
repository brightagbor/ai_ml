# %%
pip install tensorflow
# Out:
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# Requirement already satisfied: tensorflow in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf>=5.28.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (6.33.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.65.5)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (3.13.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: rich in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow) (3.7)
# Requirement already satisfied: pillow in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow) (10.4.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices("GPU")
# Out:
# 2026-01-22 17:26:28.666890: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !nvidia-smi
# Out:
# Thu Jan 22 17:26:30 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.09             Driver Version: 580.126.09     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Quadro RTX 4000                Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   47C    P8             10W /  110W |       9MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2439      G   /usr/lib/xorg/Xorg                        4MiB |
# +-----------------------------------------------------------------------------------------+

# %%
tf.__version__
# Out:
# '2.20.0'

# %%
import tensorflow as tf
