# %% [markdown]
# ### Feature Extraction - Multiclass (Using Inception_ResNetV2 with Callbacks)
#
# **AIM**: Build and train an image classifier to detect images from different animal species using a pre-trained Inception_ResNetV2 model with models from Keras Hub

# %% [markdown]
# ### Objectives
# - Install TensorFlow Hub
# - Data visualisation
# - Data preprocessing and image augmentation
# - Use a pre-trained CNN Model for transfer learning (dynamic feature extraction)
# - Base model runs every epoch and supports data augmentation and fine-tuning
# - Compile and train the model
# - Add early stopping callback (optional)
# - Save and load model
# - Model evaluation
# - Make prediction on new data
#
# ### Prerequisite
# - Google colab or Jupyter notebook
# - animal-image-classification-dataset
# - TensorFlow2

# %% [markdown]
# ### Check if TensorFlow, NumPy, Pandas and Matplotlib are installed

# %%
# !pip show tensorflow
# !pip install tensorflow-hub
# !pip install tf-keras # This is required to use hub.KerasLayer
# Out:
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# Name: tensorflow
# Version: 2.19.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, requests, setuptools, six, tensorboard, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by: spektral, tensorflow-gnn, tensorflow-text, tf_keras
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# Requirement already satisfied: tensorflow-hub in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (0.16.1)
# Requirement already satisfied: numpy>=1.12.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow-hub) (1.26.4)
# Requirement already satisfied: protobuf>=3.19.6 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow-hub) (5.29.5)
# Requirement already satisfied: tf-keras>=2.14.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow-hub) (2.19.0)
# Requirement already satisfied: tensorflow<2.20,>=2.19 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tf-keras>=2.14.1->tensorflow-hub) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.3.0)
# Requirement already satisfied: packaging in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (24.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.32.3)
# Requirement already satisfied: setuptools in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (1.65.5)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.13.1)
# Requirement already satisfied: h5py>=3.11.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.5.4)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.43.0)
# Requirement already satisfied: rich in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (13.7.1)
# Requirement already satisfied: namex in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.0.8)
# Requirement already satisfied: optree in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras>=2.14.1->tensorflow-hub) (0.1.2)
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# Requirement already satisfied: tf-keras in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (2.19.0)
# Requirement already satisfied: tensorflow<2.20,>=2.19 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tf-keras) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.3.0)
# Requirement already satisfied: packaging in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.65.5)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.13.1)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.5.4)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow<2.20,>=2.19->tf-keras) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow<2.20,>=2.19->tf-keras) (0.43.0)
# Requirement already satisfied: rich in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (13.7.1)
# Requirement already satisfied: namex in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.0.8)
# Requirement already satisfied: optree in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow<2.20,>=2.19->tf-keras) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow<2.20,>=2.19->tf-keras) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow<2.20,>=2.19->tf-keras) (0.1.2)
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)

# %%
# !pip show numpy

# %%
# !pip show pandas

# %%
# !pip show matplotlib
# Out:
# WARNING: Ignoring invalid distribution ~ensorflow (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (/home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages)
# Name: matplotlib
# Version: 3.7.5
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: /home/agbor/anaconda3/envs/tf/lib/python3.11/site-packages
# Requires: contourpy, cycler, fonttools, kiwisolver, numpy, packaging, pillow, pyparsing, python-dateutil
# Required-by: captum, catboost, missingno, pandas-profiling, phik, pycaret, pyod, pytorch-tabular, SALib, scikit-plot, seaborn, wordcloud, ydata-profiling, yellowbrick

# %%
import os

# Set the environment variable which tells TensorFlow to load the "Legacy Keras" 
# (which is essentially the Keras 2.x (tf-keras) code frozen within the TensorFlow ecosystem)
# rather than the new, multi-backend Keras 3.

os.environ['TF_USE_LEGACY_KERAS'] = '1'

import tensorflow as tf
import tensorflow_hub as hub
# Out:
# 2026-02-20 00:57:23.434556: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771545443.449507   93668 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771545443.453917   93668 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771545443.464759   93668 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771545443.464778   93668 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771545443.464780   93668 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771545443.464781   93668 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-20 00:57:23.468506: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import sys
import random
import pathlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set seed for reproducibility

SEED = 42
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Check for GPU
# !nvidia-smi
# Out:
# Fri Feb 20 00:57:25 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.09             Driver Version: 580.126.09     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Quadro RTX 4000                Off |   00000000:01:00.0  On |                  N/A |
# | N/A   49C    P8              9W /  110W |      75MiB /   8192MiB |     29%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2974      G   /usr/lib/xorg/Xorg                       69MiB |
# +-----------------------------------------------------------------------------------------+

# %%
# Check if TensorFlow can detect any GPU
gpus = tf.config.list_physical_devices("GPU")

if gpus:
    print(f"GPUs available: {len(gpus)}")

    for gpu in gpus:
        print(f"- {gpu}")
else:
    print("No GPUs found.")
# Out:
# GPUs available: 1
# - PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
gpus = tf.config.list_physical_devices("GPU")
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Get the total number of GPUs and names
if gpus:
    print(f"Total number of GPUs: {len(gpus)}")
    
    for gpu in gpus:
        print(f"GPU Name: {gpu}")
else:
    print("No GPU available")
# Out:
# Total number of GPUs: 1
# GPU Name: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
# Check TensorFlow version
print(f"TensorFlow Version: {tf.__version__}")
# Out:
# TensorFlow Version: 2.19.0

# %%
# CReate a director called "models" to store model files during training

if not os.path.isdir("models"):
    os.mkdir("models")

# %%
## Set the base path
base_dir = "../../datasets/dog_vs_cats"
base_dir = pathlib.Path(base_dir)
base_dir
# Out:
# PosixPath('../../datasets/dog_vs_cats')

# %%
# Train directory
train_dir = base_dir / "train"
train_dir
# Out:
# PosixPath('../../datasets/dog_vs_cats/train')

# %%
# Validation directory
test_dir = base_dir / "test"
test_dir
# Out:
# PosixPath('../../datasets/dog_vs_cats/test')

# %%
# Validation directory
validation_dir = base_dir / "validation"
validation_dir
# Out:
# PosixPath('../../datasets/dog_vs_cats/validation')

# %%
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224
BATCH_SIZE = 32
EPOCHS = 30

# %%
# Load the training dataset
# Using `image_dataset_from_directory (recommended and stable)
# Instead of using the 'ImageDataGenerator()' class

train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE,
    seed=SEED,
)
# Out:
# Found 20000 files belonging to 2 classes.
# I0000 00:00:1771545446.783331   93668 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6555 MB memory:  -> device: 0, name: Quadro RTX 4000, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
# Load the validation dataset

validation_dataset = tf.keras.utils.image_dataset_from_directory(
    validation_dir,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE,
    seed=SEED,
)
# Out:
# Found 5000 files belonging to 2 classes.

# %%
# Load the validation dataset

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE,
    seed=SEED,
)
# Out:
# Found 12461 files belonging to 2 classes.

# %%
# Get the class names
class_names = train_dataset.class_names
number_classes = len(class_names)

print(f"Number of classes: {number_classes}")
print(f"Class names: {list(class_names)}")
# Out:
# Number of classes: 2
# Class names: ['cats', 'dogs']

# %% [markdown]
# ### Sanity Check: Visualise dataset samples
# - Confirms correct labels
# - Detects corrupt images
# - Verifies colour channels, orientation, resolution

# %%
# Verify (test)

train_dataset.take(1)
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
# Capture exactly ONE batch and store it in memory
# This "freezes" the random augmentations for this specific set
for images, labels in train_dataset.take(1):
    fixed_images = images.numpy()
    fixed_labels = labels.numpy()
# Out:
# 2026-02-20 00:57:28.194091: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Visualisation
# No matter how many times you run this cell, the images won't change.
plt.figure(figsize=(12, 12))
for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(fixed_images[i].astype("uint8"))
    plt.title(class_names[fixed_labels[i]])
    plt.axis("off")

# %% [markdown]
# ### Performance Optimisation
#
# Using `tf.data.AUTOTUNE` and the specific method below creates an asynchronous pipeline—basically, it allows the CPU to prepare the next batch while the GPU is still processing the current one.

# %%
# AUTOTUNE allows TensorFlow to dynamically adjust the resource allocation 
# (like CPU threads) based on your hardware's current workload at runtime.
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = (
    train_dataset
    # Keep the data in memory (RAM) after the first epoch.
    # This prevents the CPU from having to re-read and re-decode JPEGs 
    # from the slow hard drive during every subsequent training round.
    .cache()

    # Maintain a buffer of 1,000 samples and randomly pulls from it.
    # This ensures the model doesn't learn the order of the files, 
    # but rather the features of the images.
    .shuffle(1000)

    # Overlaps the data preprocessing and model execution.
    # While the GPU is training on the current batch, the CPU is already 
    # preparing the next batch in the background. This eliminates "GPU starvation."
    .prefetch(buffer_size=AUTOTUNE)
)

# %%
validation_dataset = (
    validation_dataset
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)

# %%
test_dataset = (
    test_dataset
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)

# %% [markdown]
# ### Configure Callbacks

# %%
import datetime

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath="models/InceptionV2.keras",
    monitor="val_accuracy",
    save_best_only=True,
    # verbose=1
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=15,
    restore_best_weights=True,
    verbose=1
)

reduce_learning_rate = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.3,
    patience=5,
    verbose=1
)

model_path = pathlib.Path("models")
log_dir = model_path / "Inception_ResNetV2" / datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard = tf.keras.callbacks.TensorBoard(
    log_dir=log_dir,
)

model_name = "Inception_ResNetV2"
file_name = model_path / f"{model_name}training_metrics.csv"
csv_logger = tf.keras.callbacks.CSVLogger(
    filename=file_name,
    separator=",",
    append=False,
)

callbacks = [model_checkpoint, tensorboard, csv_logger, early_stopping, reduce_learning_rate]

# %% [markdown]
# ### Data Augmentation (Modern Keras Layers)

# %%
# Data Augmentation

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
])

# %% [markdown]
# ### Model Input Shape

# %%
INPUT_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH) + (3,)
INPUT_SHAPE
# Out:
# (224, 224, 3)

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers, models

# %%
### Function to build model

def buildModel(model_url, num_classes=1000, input_shape=(224, 224, 3)):

    """
    Takes a TensorFlow Hub (or Keras Hub) URL and creates a Keras Sequential class with it.

    Args:
        model_url (str): A TensorFlow Hub feature extration URL
        num_lasses (int): Number of output neurons in the output layer 
            (1 == binary, num_classes == multiclass classification),
            This numbe rshould be equal to number of target classes.      

    Returns:
        An unompiled Keras Sequential model with model_url as feature extractor
        layer and Dense output layer with num_classes output neurons.
    """

    # Download the pretrained model and save it as  a Keras layer
    feature_extractor_layer = hub.KerasLayer(model_url,
                                             trainable=False,
                                             name="feature_extration_layer",
                                             input_shape=input_shape) # Freeze the already learnt patterns
    
    # Create the classification head
    model = tf.keras.Sequential([
        feature_extractor_layer,
        layers.Dense(256, activation="relu", name="dense_layer_1"),
        layers.Dropout(0.25),
        layers.BatchNormalization(),
        layers.Dense(num_classes, 
                     activation="sigmoid" if num_classes==1 else "softmax",
                     name="output_layer")
    ])
        
    return model

# %% [markdown]
# ### Creating the Inception_ResNetV2 Model

# %%
inception_restnetv2_url = "https://www.kaggle.com/models/google/inception-resnet-v2/TensorFlow2/feature-vector/2"

name = "Inception_ResNetV2_model"
model = buildModel(inception_restnetv2_url, 
                   num_classes=1, 
                   input_shape=INPUT_SHAPE)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extration_layer (K  (None, 1536)              54336736
#  erasLayer)
#
#  dense_layer_1 (Dense)       (None, 256)               393472
#
#  dropout (Dropout)           (None, 256)               0
#
#  batch_normalization (Batch  (None, 256)               1024
#  Normalization)
#
#  output_layer (Dense)        (None, 1)                 257
#
# =================================================================
# Total params: 54731489 (208.78 MB)
# Trainable params: 394241 (1.50 MB)
# Non-trainable params: 54337248 (207.28 MB)
# _________________________________________________________________

# %%
num_classes = 1
activation="sigmoid" if num_classes==1 else "softmax"
activation
# Out:
# 'sigmoid'

# %% [markdown]
# ### Build and Compile the Model

# %%
# Compile the model

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-7),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)

# %% [markdown]
# ### Train the model to learn patterns from the images

# %%
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/30
# I0000 00:00:1771545568.343396   93791 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 2026-02-20 00:59:29.581310: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 7.03GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771545570.722738   93794 service.cc:152] XLA service 0x792f507d3760 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771545570.722756   93794 service.cc:160]   StreamExecutor device (0): Quadro RTX 4000, Compute Capability 7.5
# 2026-02-20 00:59:30.727607: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1771545570.817410   93794 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 625/625 [==============================] - 122s 168ms/step - loss: 0.7856 - accuracy: 0.4996 - val_loss: 0.6961 - val_accuracy: 0.5170 - lr: 1.0000e-07
# Epoch 2/30
# 625/625 [==============================] - 104s 166ms/step - loss: 0.7776 - accuracy: 0.5074 - val_loss: 0.6933 - val_accuracy: 0.5386 - lr: 1.0000e-07
# Epoch 3/30
# 625/625 [==============================] - 104s 166ms/step - loss: 0.7704 - accuracy: 0.5152 - val_loss: 0.6824 - val_accuracy: 0.5518 - lr: 1.0000e-07
# Epoch 4/30
# 625/625 [==============================] - 104s 167ms/step - loss: 0.7690 - accuracy: 0.5124 - val_loss: 0.6793 - val_accuracy: 0.5662 - lr: 1.0000e-07
# Epoch 5/30
# 625/625 [==============================] - 104s 167ms/step - loss: 0.7568 - accuracy: 0.5277 - val_loss: 0.6757 - val_accuracy: 0.5728 - lr: 1.0000e-07
# Epoch 6/30
# 625/625 [==============================] - 104s 166ms/step - loss: 0.7559 - accuracy: 0.5298 - val_loss: 0.6729 - val_accuracy: 0.5778 - lr: 1.0000e-07
# Epoch 7/30
# 625/625 [==============================] - 104s 167ms/step - loss: 0.7553 - accuracy: 0.5354 - val_loss: 0.6719 - val_accuracy: 0.5808 - lr: 1.0000e-07
# Epoch 8/30
# 625/625 [==============================] - 105s 168ms/step - loss: 0.7565 - accuracy: 0.5320 - val_loss: 0.6702 - val_accuracy: 0.5836 - lr: 1.0000e-07
# Epoch 9/30
# 625/625 [==============================] - 105s 168ms/step - loss: 0.7467 - accuracy: 0.5426 - val_loss: 0.6705 - val_accuracy: 0.5878 - lr: 1.0000e-07
# Epoch 10/30
# 625/625 [==============================] - 105s 168ms/step - loss: 0.7468 - accuracy: 0.5401 - val_loss: 0.6697 - val_accuracy: 0.5894 - lr: 1.0000e-07
# Epoch 11/30
# 625/625 [==============================] - 105s 168ms/step - loss: 0.7452 - accuracy: 0.5425 - val_loss: 0.6675 - val_accuracy: 0.5908 - lr: 1.0000e-07
# Epoch 12/30
# 625/625 [==============================] - 105s 168ms/step - loss: 0.7414 - accuracy: 0.5477 - val_loss: 0.6684 - val_accuracy: 0.5914 - lr: 1.0000e-07
# Epoch 13/30
# 625/625 [==============================] - 105s 168ms/step - loss: 0.7416 - accuracy: 0.5495 - val_loss: 0.6706 - val_accuracy: 0.5920 - lr: 1.0000e-07
# Epoch 14/30
# 625/625 [==============================] - 105s 169ms/step - loss: 0.7412 - accuracy: 0.5459 - val_loss: 0.6656 - val_accuracy: 0.5934 - lr: 1.0000e-07
# Epoch 15/30
# 625/625 [==============================] - 104s 166ms/step - loss: 0.7468 - accuracy: 0.5425 - val_loss: 0.6669 - val_accuracy: 0.5934 - lr: 1.0000e-07
# Epoch 16/30
# 625/625 [==============================] - 105s 168ms/step - loss: 0.7445 - accuracy: 0.5523 - val_loss: 0.6665 - val_accuracy: 0.5966 - lr: 1.0000e-07
# Epoch 17/30
# 625/625 [==============================] - 105s 168ms/step - loss: 0.7389 - accuracy: 0.5555 - val_loss: 0.6671 - val_accuracy: 0.5982 - lr: 1.0000e-07
# Epoch 18/30
# 625/625 [==============================] - 103s 165ms/step - loss: 0.7313 - accuracy: 0.5628 - val_loss: 0.6666 - val_accuracy: 0.5980 - lr: 1.0000e-07
# Epoch 19/30
# 625/625 [==============================] - ETA: 0s - loss: 0.7374 - accuracy: 0.5590
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.0000000350582924e-08.
# 625/625 [==============================] - 104s 167ms/step - loss: 0.7374 - accuracy: 0.5590 - val_loss: 0.6666 - val_accuracy: 0.5976 - lr: 1.0000e-07
# Epoch 20/30
# 625/625 [==============================] - 105s 167ms/step - loss: 0.7330 - accuracy: 0.5623 - val_loss: 0.6658 - val_accuracy: 0.5994 - lr: 3.0000e-08
# Epoch 21/30
# 625/625 [==============================] - 105s 167ms/step - loss: 0.7411 - accuracy: 0.5544 - val_loss: 0.6654 - val_accuracy: 0.5976 - lr: 3.0000e-08
# Epoch 22/30
# 625/625 [==============================] - 104s 167ms/step - loss: 0.7380 - accuracy: 0.5544 - val_loss: 0.6648 - val_accuracy: 0.5990 - lr: 3.0000e-08
# Epoch 23/30
# 625/625 [==============================] - 104s 167ms/step - loss: 0.7366 - accuracy: 0.5562 - val_loss: 0.6647 - val_accuracy: 0.5990 - lr: 3.0000e-08
# Epoch 24/30
# 625/625 [==============================] - 104s 166ms/step - loss: 0.7391 - accuracy: 0.5563 - val_loss: 0.6664 - val_accuracy: 0.5984 - lr: 3.0000e-08
# Epoch 25/30
# 625/625 [==============================] - 105s 168ms/step - loss: 0.7352 - accuracy: 0.5592 - val_loss: 0.6654 - val_accuracy: 0.6002 - lr: 3.0000e-08
# Epoch 26/30
# 625/625 [==============================] - 104s 166ms/step - loss: 0.7378 - accuracy: 0.5574 - val_loss: 0.6655 - val_accuracy: 0.5996 - lr: 3.0000e-08
# Epoch 27/30
# 625/625 [==============================] - ETA: 0s - loss: 0.7383 - accuracy: 0.5580
# Epoch 27: ReduceLROnPlateau reducing learning rate to 8.999999678849234e-09.
# 625/625 [==============================] - 104s 167ms/step - loss: 0.7383 - accuracy: 0.5580 - val_loss: 0.6659 - val_accuracy: 0.6000 - lr: 3.0000e-08
# Epoch 28/30
# 625/625 [==============================] - 104s 167ms/step - loss: 0.7314 - accuracy: 0.5652 - val_loss: 0.6664 - val_accuracy: 0.6002 - lr: 9.0000e-09
# Epoch 29/30
# 625/625 [==============================] - 104s 167ms/step - loss: 0.7311 - accuracy: 0.5633 - val_loss: 0.6657 - val_accuracy: 0.6008 - lr: 9.0000e-09
# Epoch 30/30
# 625/625 [==============================] - 104s 167ms/step - loss: 0.7383 - accuracy: 0.5580 - val_loss: 0.6662 - val_accuracy: 0.5998 - lr: 9.0000e-09
# Restoring model weights from the end of the best epoch: 23.

# %% [markdown]
# ### Plot Training Curves (Learning Dynamics)

# %%
file_name = model_path / f"{model_name}_training_metrics.csv"
file_name
# Out:
# PosixPath('models/Inception_ResNetV2_training_metrics.csv')

# %%
log_dir
# Out:
# PosixPath('models/Inception_ResNetV2/20260220-005729')

# %%
def plot_learning_curves(history):
    acc = history.history["accuracy"]
    val_acc = history.history["val_accuracy"]
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    epochs_range = range(len(acc))


    plt.figure(figsize=(18, 7))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label="Training Accuracy")
    plt.plot(epochs_range, val_acc, label="Validation Accuracy")
    plt.legend()
    plt.title("Accuracy")

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label="Training Loss")
    plt.plot(epochs_range, val_loss, label="Validation Loss")
    plt.legend()
    plt.title("Loss")

    plt.show()

# %%
plot_learning_curves(history)

# %% [markdown]
# ### Generate Predictions (TensorFlow to NumPy)

# %%
loss, accuracy = model.evaluate(validation_dataset)

print(f"Model Loss: {loss:.2f}")
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# 157/157 [==============================] - 21s 131ms/step - loss: 0.6647 - accuracy: 0.5990
# Model Loss: 0.66
# Model Accuracy: 0.60

# %%
y_true = []
y_pred = []
y_prob = []

for images, labels in test_dataset:
    preds = model.predict(images, verbose=1) # Try verbose=0
    y_prob.append(preds)
    y_pred.append(preds >= 0.5)
    y_true.append(labels.numpy())
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 2s 2s/step
# 2026-02-20 01:53:09.908036: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
len(y_true), len(y_pred), len(y_prob)
# Out:
# (390, 390, 390)

# %%
y_true = np.concatenate(y_true)
y_pred = np.concatenate(y_pred)
y_prob = np.concatenate(y_prob)

# %% [markdown]
# ### Core Classification Metrics (from scikit-learn)

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)



print(f"Accuracy: {accuracy_score(y_true, y_pred)}")
print(f"Precision (macro): {precision_score(y_true, y_pred)}")
print(f"Recall (macro): {recall_score(y_true, y_pred):.2f}")
print(f"F1-score (macro): {f1_score(y_true, y_pred):.2f}")
# Out:
# Accuracy: 0.6012358558703154
# Precision (macro): 0.5860644450564583
# Recall (macro): 0.68
# F1-score (macro): 0.63

# %%
# Full Classification Report

print(classification_report(
    y_true,
    y_pred,
    target_names=class_names,
    digits=4
))
# Out:
#               precision    recall  f1-score   support
#
#         cats     0.6224    0.5184    0.5657      6242
#         dogs     0.5861    0.6844    0.6314      6219
#
#     accuracy                         0.6012     12461
#    macro avg     0.6042    0.6014    0.5985     12461
# weighted avg     0.6043    0.6012    0.5985     12461

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred)
cm_norm = cm.astype("float") / cm.sum(axis=1, keepdims=True)

plt.figure(figsize=(6, 5))

# Create custom annotations showing both count and percentage
annot_text = np.empty_like(cm).astype(str)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        annot_text[i, j] = f'{cm[i, j]}\n({cm_norm[i, j]:.1%})'

sns.heatmap(cm, 
            cmap="Blues", 
            cbar=False, 
            annot=annot_text, 
            fmt='',  # fmt='' for string annotations
            xticklabels=class_names,
            yticklabels=class_names,
            
            # kwargs for annotation text
            annot_kws={"fontsize": 12, "fontweight": "bold"},)  

plt.title("Confusion Matrix (Counts and Percentages)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.xticks(rotation=45, ha="right")

# Adjust layout to prevent text cutoff
plt.tight_layout()  
plt.show()

# %%
# Saving the Model

model.save("dogs_cat_Inception_ResNetV2.keras")

# %% [markdown]
# **This resulted in a poor model. We will use transfer learning to see how to improve the model using any of the model which is already doing well in general image processing tasks.**
