# %% [markdown]
# ## Neural Architecture Search (NAS) Implementation
#
# **AIM: Build and train an image classifier to detect images from different animal species using a Custom Model derived from NAS in TensorFlow.**

# %% [markdown]
# ### Objectives
#
# - Data visualisation
# - Data preprocessing and image augmentation
# - Use NAS to derive an efficient architecture for model development.
# - Compile and train the model
# - Add early stopping callback (optional)
# - Save and load the model
# - Model evaluation.
# - Make predictions on new data using the trained model.

# %% [markdown]
# ### Pre-requisite
# - Google collaboratry or Jupyter Notebook
# - animal-image-classification-dataset
# - TensorFlow2

# %%
# Import basic libraries
import os
import sys
import random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import pathlib
# Out:
# 2026-02-08 01:24:13.266994: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770510253.283296  573477 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770510253.288799  573477 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770510253.300442  573477 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770510253.300483  573477 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770510253.300487  573477 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770510253.300489  573477 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-08 01:24:13.304791: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Set seed for reproducibility

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# Check GPU availability
# !nvidia-smi
# Out:
# Sun Feb  8 01:24:14 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.09             Driver Version: 580.126.09     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Quadro RTX 4000                Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   69C    P8              7W /  110W |       6MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            2917      G   /usr/lib/xorg/Xorg                        4MiB |
# +-----------------------------------------------------------------------------------------+

# %%
gpus= tf.config.list_physical_devices()

# %%
gpus
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
logical_devices = tf.config.list_logical_devices()
logical_devices
# Out:
# I0000 00:00:1770510255.463656  573477 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6624 MB memory:  -> device: 0, name: Quadro RTX 4000, pci bus id: 0000:01:00.0, compute capability: 7.5
# [LogicalDevice(name='/device:CPU:0', device_type='CPU'),
#  LogicalDevice(name='/device:GPU:0', device_type='GPU')]

# %%
# Check tenorflow version
print("TensorFlow Version", tf.__version__)
# Out:
# TensorFlow Version 2.19.0

# %%
## Set the base path
base_dir = "../dataset/dog_vs_cats"
base_dir = pathlib.Path(base_dir)
base_dir
# Out:
# PosixPath('../dataset/dog_vs_cats')

# %%
# Train directory
train_dir = base_dir / "train"
train_dir
# Out:
# PosixPath('../dataset/dog_vs_cats/train')

# %%
# Validation directory
validation_dir = base_dir / "validation"
validation_dir
# Out:
# PosixPath('../dataset/dog_vs_cats/validation')

# %%
# Test directory
test_dir = base_dir / "test"
test_dir
# Out:
# PosixPath('../dataset/dog_vs_cats/test')

# %%
## Set Hyperparameters

IMAGE_HEIGHT, IMAGE_WIDTH = 128, 128
BATCH_SIZE = 32
EPOCHS = 300

# %%
# Load the training dataset

train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE,
    seed=SEED,
)
# Out:
# Found 20000 files belonging to 2 classes.

# %%
# Load the validation dataset

validation_dataset = tf.keras.utils.image_dataset_from_directory(
    validation_dir,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE,
    seed=SEED,
)
# Out:
# Found 5000 files belonging to 2 classes.

# %%
# Load the validation dataset

test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
    batch_size=BATCH_SIZE,
    seed=SEED,
)
# Out:
# Found 12461 files belonging to 2 classes.

# %%
# Get the class names
class_names = train_dataset.class_names
class_names
# Out:
# ['cats', 'dogs']

# %%
# Get the total number of classes
num_classes = len(class_names)
num_classes
# Out:
# 2

# %%
# Sanity check

for images, labels in train_dataset.take(1):
    fixed_images = images.numpy()
    fixed_labels = labels.numpy()


# Visualisations
# No matter how many times you run this cell, the images won change because of teh above

plt.figure(figsize=(12, 12))
for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(fixed_images[i].astype("uint8"))
    plt.title(class_names[fixed_labels[i]])
    plt.axis("off")
# Out:
# 2026-02-08 01:24:17.094356: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
# Performance optimization

# %% [markdown]
# ### Vanilla MobileNetV2 Implementation

# %%
INPUT_SHAPE = (IMAGE_HEIGHT, IMAGE_WIDTH) + (3, )
INPUT_SHAPE
# Out:
# (128, 128, 3)

# %% [markdown]
# ### Performance Optimisation

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
validation_dataset = validation_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Data Augmentation Step

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
    # tf.keras.layers.RandomTranslation(0.15, 0.15),
    # tf.keras.layers.RandomContrast(0.25),
    # tf.keras.layers.RandomBrightness(0.2),
    # tf.keras.layers.GaussianNoise(0.05),
    # tf.keras.layers.RandomErasing(),
])

# %% [markdown]
# ### Neural Architecture Search Implementation

# %%
# Inputs
inputs = tf.keras.layers.Input(shape=INPUT_SHAPE)
inputs
# Out:
# <KerasTensor shape=(None, 128, 128, 3), dtype=float32, sparse=False, ragged=False, name=keras_tensor>

# %%
import keras_tuner

# %% [markdown]
# ### (a). Define Search Space (Model Builder Function)

# %%
# This function tells NAS what architeture choices it can eplore

def build_model(hp):
    model = tf.keras.Sequential()

    model.add(tf.keras.layers.Input(shape=INPUT_SHAPE))

    # Data augmentation inside model (good for .fit)
    model.add(data_augmentation)

    # Search number of CNN layers
    for i in range(hp.Int("conv_layers", 1, 4)):
        model.add(
            tf.keras.layers.Conv2D(
                filters=hp.Int(f"filters_{i}", 32, 256, step=16),
                kernel_size=hp.Choice("kernel_size", [3, 5]),
                activation="relu",
                padding="same"
            )
        )

        model.add(tf.keras.layers.BatchNormalization())

        if hp.Boolean("use_pooling"):
            model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
        
    model.add(tf.keras.layers.GlobalAveragePooling2D())


    # Dense layer search
    model.add(
        tf.keras.layers.Dense(
            units=hp.Int("dense_units", 16, 512, step=16),
            activation="relu"
        )
    )

    # Dropout search
    model.add(tf.keras.layers.Dropout(
        hp.Float("dropout", 0.1, 0.5, step=0.1)
    ))

    model.add(tf.keras.layers.Dense(1, activation="sigmoid"))


    # Learning rate search
    model.compile(
        optimizer=tf.keras.optimizers.Adam(
            hp.Choice("learning_rate", [1e-2, 1e-3, 1e-4])
        ),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %% [markdown]
# ### Initialise NAS Search Engine (Hyperband)

# %%
import keras_tuner as kt

tuner = kt.Hyperband(
    build_model,
    objective="val_accuracy",
    max_epochs=15,
    factor=3,
    directory="nas_cnn_results",
    project_name="cnn_nas"
)

# %% [markdown]
# ### Start Architecture Search

# %%
tuner.search(
    train_dataset,
    validation_data=validation_dataset,
    epochs=100,
    batch_size=BATCH_SIZE,
)
# Out:
# Trial 30 Complete [00h 18m 29s]
# val_accuracy: 0.7702000141143799
#
# Best val_accuracy So Far: 0.7702000141143799
# Total elapsed time: 04h 45m 35s

# %% [markdown]
# ### SHow Best Model Parameters

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best Hyperparameters Found:")
for key in best_hps.values.keys():
    print(f"{key}: {best_hps.get(key)}")
# Out:
# Best Hyperparameters Found:
# conv_layers: 3
# filters_0: 192
# kernel_size: 5
# use_pooling: True
# dense_units: 16
# dropout: 0.1
# learning_rate: 0.01
# filters_1: 144
# filters_2: 64
# filters_3: 208
# tuner/epochs: 15
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0

# %% [markdown]
# ### Show Best CNN Architecture Found

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 192)  │        14,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 192)  │           768 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 192)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 144)    │       691,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 144)    │           576 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 144)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 64)     │       230,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │         1,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 939,057 (3.58 MB)
#  Trainable params: 938,257 (3.58 MB)
#  Non-trainable params: 800 (3.12 KB)

# %% [markdown]
# ### Print Each CNN Layer and Its Parameters

# %%
for layer in best_model.layers:
    print(f"Layer: {layer.name}")
    print("  Config:", layer.get_config())
# Out:
# Layer: sequential
#   Config: {'name': 'sequential', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'layers': [{'module': 'keras.layers', 'class_name': 'InputLayer', 'config': {'batch_shape': (None, 128, 128, 3), 'dtype': 'float32', 'sparse': False, 'ragged': False, 'name': 'input_layer_2', 'optional': False}, 'registered_name': None}, {'module': 'keras.layers', 'class_name': 'Rescaling', 'config': {'name': 'rescaling', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'scale': 0.00392156862745098, 'offset': 0.0}, 'registered_name': None, 'build_config': {'input_shape': (None, 128, 128, 3)}}, {'module': 'keras.layers', 'class_name': 'RandomFlip', 'config': {'name': 'random_flip', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'seed': None, 'mode': 'horizontal_and_vertical', 'data_format': 'channels_last'}, 'registered_name': None, 'build_config': {'input_shape': (None, 128, 128, 3)}}, {'module': 'keras.layers', 'class_name': 'RandomRotation', 'config': {'name': 'random_rotation', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'factor': (-0.2, 0.2), 'data_format': 'channels_last', 'fill_mode': 'reflect', 'fill_value': 0.0, 'interpolation': 'bilinear', 'seed': None}, 'registered_name': None, 'build_config': {'input_shape': (None, 128, 128, 3)}}, {'module': 'keras.layers', 'class_name': 'RandomZoom', 'config': {'name': 'random_zoom', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'height_factor': 0.2, 'width_factor': None, 'fill_mode': 'reflect', 'interpolation': 'bilinear', 'seed': None, 'fill_value': 0.0, 'data_format': 'channels_last'}, 'registered_name': None, 'build_config': {'input_shape': (None, 128, 128, 3)}}], 'build_input_shape': (None, 128, 128, 3)}
# Layer: conv2d
#   Config: {'name': 'conv2d', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'filters': 192, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# Layer: batch_normalization
#   Config: {'name': 'batch_normalization', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'axis': -1, 'momentum': 0.99, 'epsilon': 0.001, 'center': True, 'scale': True, 'beta_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'gamma_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'moving_mean_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'moving_variance_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None, 'synchronized': False}
# Layer: max_pooling2d
#   Config: {'name': 'max_pooling2d', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}
# Layer: conv2d_1
#   Config: {'name': 'conv2d_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'filters': 144, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# Layer: batch_normalization_1
#   Config: {'name': 'batch_normalization_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'axis': -1, 'momentum': 0.99, 'epsilon': 0.001, 'center': True, 'scale': True, 'beta_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'gamma_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'moving_mean_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'moving_variance_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None, 'synchronized': False}
# Layer: max_pooling2d_1
#   Config: {'name': 'max_pooling2d_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}
# Layer: conv2d_2
#   Config: {'name': 'conv2d_2', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'filters': 64, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# Layer: batch_normalization_2
#   Config: {'name': 'batch_normalization_2', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'axis': -1, 'momentum': 0.99, 'epsilon': 0.001, 'center': True, 'scale': True, 'beta_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'gamma_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'moving_mean_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'moving_variance_initializer': {'module': 'keras.initializers', 'class_name': 'Ones', 'config': {}, 'registered_name': None}, 'beta_regularizer': None, 'gamma_regularizer': None, 'beta_constraint': None, 'gamma_constraint': None, 'synchronized': False}
# Layer: max_pooling2d_2
#   Config: {'name': 'max_pooling2d_2', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'pool_size': (2, 2), 'padding': 'valid', 'strides': (2, 2), 'data_format': 'channels_last'}
# Layer: global_average_pooling2d
#   Config: {'name': 'global_average_pooling2d', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'data_format': 'channels_last', 'keepdims': False}
# Layer: dense
#   Config: {'name': 'dense', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'units': 16, 'activation': 'relu', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None, 'quantization_config': None}
# Layer: dropout
#   Config: {'name': 'dropout', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'rate': 0.1, 'seed': None, 'noise_shape': None}
# Layer: dense_1
#   Config: {'name': 'dense_1', 'trainable': True, 'dtype': {'module': 'keras', 'class_name': 'DTypePolicy', 'config': {'name': 'float32'}, 'registered_name': None}, 'units': 1, 'activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None, 'quantization_config': None}

# %% [markdown]
# ### Save Best Hyperparameters to File

# %%
import json

with open("best_nas_hyperparameters.json", "w") as f:
    json.dump(best_hps.values, f, indent=4)
print("Done")
# Out:
# Done

# %%
model = best_model

# %%
# Configure Callbacks

model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    filepath="models/nas_implementation_SMBO.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=10,
    verbose=1,
    restore_best_weights=True
)

reduce_learning_rate = tf.keras.callbacks.ReduceLROnPlateau(
    monitor="val_loss",
    patience=5,
    factor=0.3,
    verbose=1
)

callbacks = [model_checkpoint, early_stopping, reduce_learning_rate]

# %% [markdown]
# # Train the best CNN Model Fully

# %%
# # Train the Model to learn patterns from the image

history = best_model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks
)
# Out:
# Epoch 1/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7461 - loss: 0.5241
# Epoch 1: val_accuracy improved from None to 0.72440, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 1: finished saving model to models/nas_implementation_SMBO.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 76s 118ms/step - accuracy: 0.7460 - loss: 0.5259 - val_accuracy: 0.7244 - val_loss: 0.5324 - learning_rate: 0.0100
# Epoch 2/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7495 - loss: 0.5118
# Epoch 2: val_accuracy improved from 0.72440 to 0.75480, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 2: finished saving model to models/nas_implementation_SMBO.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 74s 118ms/step - accuracy: 0.7556 - loss: 0.5066 - val_accuracy: 0.7548 - val_loss: 0.4954 - learning_rate: 0.0100
# Epoch 3/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7641 - loss: 0.4975
# Epoch 3: val_accuracy did not improve from 0.75480
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.7642 - loss: 0.4967 - val_accuracy: 0.6956 - val_loss: 0.5846 - learning_rate: 0.0100
# Epoch 4/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7669 - loss: 0.4844
# Epoch 4: val_accuracy improved from 0.75480 to 0.76580, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 4: finished saving model to models/nas_implementation_SMBO.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 118ms/step - accuracy: 0.7681 - loss: 0.4852 - val_accuracy: 0.7658 - val_loss: 0.5099 - learning_rate: 0.0100
# Epoch 5/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7738 - loss: 0.4776
# Epoch 5: val_accuracy improved from 0.76580 to 0.77860, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 5: finished saving model to models/nas_implementation_SMBO.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 74s 118ms/step - accuracy: 0.7746 - loss: 0.4804 - val_accuracy: 0.7786 - val_loss: 0.4775 - learning_rate: 0.0100
# Epoch 6/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7828 - loss: 0.4668
# Epoch 6: val_accuracy improved from 0.77860 to 0.78280, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 6: finished saving model to models/nas_implementation_SMBO.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 118ms/step - accuracy: 0.7810 - loss: 0.4678 - val_accuracy: 0.7828 - val_loss: 0.4710 - learning_rate: 0.0100
# Epoch 7/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.7879 - loss: 0.4565
# Epoch 7: val_accuracy improved from 0.78280 to 0.78340, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 7: finished saving model to models/nas_implementation_SMBO.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.7854 - loss: 0.4581 - val_accuracy: 0.7834 - val_loss: 0.4602 - learning_rate: 0.0100
# Epoch 8/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7897 - loss: 0.4493
# Epoch 8: val_accuracy did not improve from 0.78340
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.7897 - loss: 0.4509 - val_accuracy: 0.7640 - val_loss: 0.4944 - learning_rate: 0.0100
# Epoch 9/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8037 - loss: 0.4350
# Epoch 9: val_accuracy did not improve from 0.78340
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.7982 - loss: 0.4402 - val_accuracy: 0.7300 - val_loss: 0.5173 - learning_rate: 0.0100
# Epoch 10/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8079 - loss: 0.4245
# Epoch 10: val_accuracy did not improve from 0.78340
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8072 - loss: 0.4240 - val_accuracy: 0.7800 - val_loss: 0.4800 - learning_rate: 0.0100
# Epoch 11/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8068 - loss: 0.4271
# Epoch 11: val_accuracy did not improve from 0.78340
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8107 - loss: 0.4216 - val_accuracy: 0.7796 - val_loss: 0.4963 - learning_rate: 0.0100
# Epoch 12/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.8072 - loss: 0.4162
# Epoch 12: val_accuracy did not improve from 0.78340
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0029999999329447745.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8073 - loss: 0.4193 - val_accuracy: 0.7494 - val_loss: 0.5227 - learning_rate: 0.0100
# Epoch 13/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8326 - loss: 0.3800
# Epoch 13: val_accuracy improved from 0.78340 to 0.83460, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 13: finished saving model to models/nas_implementation_SMBO.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8311 - loss: 0.3801 - val_accuracy: 0.8346 - val_loss: 0.3693 - learning_rate: 0.0030
# Epoch 14/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8339 - loss: 0.3731
# Epoch 14: val_accuracy did not improve from 0.83460
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8335 - loss: 0.3721 - val_accuracy: 0.8300 - val_loss: 0.3685 - learning_rate: 0.0030
# Epoch 15/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8331 - loss: 0.3707
# Epoch 15: val_accuracy did not improve from 0.83460
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8359 - loss: 0.3663 - val_accuracy: 0.8082 - val_loss: 0.4238 - learning_rate: 0.0030
# Epoch 16/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8413 - loss: 0.3580
# Epoch 16: val_accuracy did not improve from 0.83460
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8393 - loss: 0.3633 - val_accuracy: 0.7878 - val_loss: 0.5054 - learning_rate: 0.0030
# Epoch 17/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8383 - loss: 0.3663
# Epoch 17: val_accuracy did not improve from 0.83460
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8412 - loss: 0.3624 - val_accuracy: 0.8322 - val_loss: 0.3728 - learning_rate: 0.0030
# Epoch 18/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8475 - loss: 0.3483
# Epoch 18: val_accuracy improved from 0.83460 to 0.85300, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 18: finished saving model to models/nas_implementation_SMBO.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8450 - loss: 0.3536 - val_accuracy: 0.8530 - val_loss: 0.3439 - learning_rate: 0.0030
# Epoch 19/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8457 - loss: 0.3518
# Epoch 19: val_accuracy improved from 0.85300 to 0.85620, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 19: finished saving model to models/nas_implementation_SMBO.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8442 - loss: 0.3558 - val_accuracy: 0.8562 - val_loss: 0.3395 - learning_rate: 0.0030
# Epoch 20/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8485 - loss: 0.3470
# Epoch 20: val_accuracy did not improve from 0.85620
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8473 - loss: 0.3471 - val_accuracy: 0.8408 - val_loss: 0.3703 - learning_rate: 0.0030
# Epoch 21/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8484 - loss: 0.3459
# Epoch 21: val_accuracy did not improve from 0.85620
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8504 - loss: 0.3446 - val_accuracy: 0.8190 - val_loss: 0.4227 - learning_rate: 0.0030
# Epoch 22/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8457 - loss: 0.3443
# Epoch 22: val_accuracy did not improve from 0.85620
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8511 - loss: 0.3405 - val_accuracy: 0.8534 - val_loss: 0.3355 - learning_rate: 0.0030
# Epoch 23/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8502 - loss: 0.3368
# Epoch 23: val_accuracy did not improve from 0.85620
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 72s 116ms/step - accuracy: 0.8496 - loss: 0.3414 - val_accuracy: 0.8144 - val_loss: 0.3925 - learning_rate: 0.0030
# Epoch 24/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8568 - loss: 0.3349
# Epoch 24: val_accuracy did not improve from 0.85620
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8569 - loss: 0.3340 - val_accuracy: 0.8324 - val_loss: 0.3768 - learning_rate: 0.0030
# Epoch 25/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8518 - loss: 0.3350
# Epoch 25: val_accuracy did not improve from 0.85620
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 116ms/step - accuracy: 0.8525 - loss: 0.3325 - val_accuracy: 0.8552 - val_loss: 0.3275 - learning_rate: 0.0030
# Epoch 26/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8579 - loss: 0.3326
# Epoch 26: val_accuracy did not improve from 0.85620
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 72s 116ms/step - accuracy: 0.8569 - loss: 0.3336 - val_accuracy: 0.8348 - val_loss: 0.3686 - learning_rate: 0.0030
# Epoch 27/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8630 - loss: 0.3198
# Epoch 27: val_accuracy did not improve from 0.85620
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8571 - loss: 0.3264 - val_accuracy: 0.8280 - val_loss: 0.3853 - learning_rate: 0.0030
# Epoch 28/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8565 - loss: 0.3261
# Epoch 28: val_accuracy did not improve from 0.85620
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8567 - loss: 0.3271 - val_accuracy: 0.8528 - val_loss: 0.3404 - learning_rate: 0.0030
# Epoch 29/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8615 - loss: 0.3194
# Epoch 29: val_accuracy did not improve from 0.85620
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8593 - loss: 0.3250 - val_accuracy: 0.8254 - val_loss: 0.3985 - learning_rate: 0.0030
# Epoch 30/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8645 - loss: 0.3103
# Epoch 30: val_accuracy did not improve from 0.85620
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8603 - loss: 0.3194 - val_accuracy: 0.8488 - val_loss: 0.3410 - learning_rate: 0.0030
# Epoch 31/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8702 - loss: 0.3028
# Epoch 31: val_accuracy did not improve from 0.85620
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8683 - loss: 0.3067 - val_accuracy: 0.8492 - val_loss: 0.3425 - learning_rate: 9.0000e-04
# Epoch 32/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8691 - loss: 0.2998
# Epoch 32: val_accuracy improved from 0.85620 to 0.86540, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 32: finished saving model to models/nas_implementation_SMBO.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8677 - loss: 0.3017 - val_accuracy: 0.8654 - val_loss: 0.3076 - learning_rate: 9.0000e-04
# Epoch 33/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8696 - loss: 0.3005
# Epoch 33: val_accuracy did not improve from 0.86540
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8701 - loss: 0.2979 - val_accuracy: 0.8480 - val_loss: 0.3517 - learning_rate: 9.0000e-04
# Epoch 34/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8785 - loss: 0.2859
# Epoch 34: val_accuracy did not improve from 0.86540
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8716 - loss: 0.2998 - val_accuracy: 0.8596 - val_loss: 0.3227 - learning_rate: 9.0000e-04
# Epoch 35/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8715 - loss: 0.2949
# Epoch 35: val_accuracy did not improve from 0.86540
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8723 - loss: 0.2974 - val_accuracy: 0.8590 - val_loss: 0.3272 - learning_rate: 9.0000e-04
# Epoch 36/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8750 - loss: 0.2917
# Epoch 36: val_accuracy improved from 0.86540 to 0.86780, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 36: finished saving model to models/nas_implementation_SMBO.keras
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8719 - loss: 0.2963 - val_accuracy: 0.8678 - val_loss: 0.3085 - learning_rate: 9.0000e-04
# Epoch 37/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8746 - loss: 0.2915
# Epoch 37: val_accuracy improved from 0.86780 to 0.87020, saving model to models/nas_implementation_SMBO.keras
#
# Epoch 37: finished saving model to models/nas_implementation_SMBO.keras
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8722 - loss: 0.2924 - val_accuracy: 0.8702 - val_loss: 0.3085 - learning_rate: 9.0000e-04
# Epoch 38/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8768 - loss: 0.2887
# Epoch 38: val_accuracy did not improve from 0.87020
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8755 - loss: 0.2895 - val_accuracy: 0.8530 - val_loss: 0.3471 - learning_rate: 2.7000e-04
# Epoch 39/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8782 - loss: 0.2868
# Epoch 39: val_accuracy did not improve from 0.87020
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8745 - loss: 0.2921 - val_accuracy: 0.8626 - val_loss: 0.3217 - learning_rate: 2.7000e-04
# Epoch 40/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8770 - loss: 0.2860
# Epoch 40: val_accuracy did not improve from 0.87020
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8762 - loss: 0.2874 - val_accuracy: 0.8584 - val_loss: 0.3324 - learning_rate: 2.7000e-04
# Epoch 41/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8787 - loss: 0.2809
# Epoch 41: val_accuracy did not improve from 0.87020
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 117ms/step - accuracy: 0.8761 - loss: 0.2855 - val_accuracy: 0.8432 - val_loss: 0.3647 - learning_rate: 2.7000e-04
# Epoch 42/300
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8719 - loss: 0.2972
# Epoch 42: val_accuracy did not improve from 0.87020
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 8.099999686237424e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 73s 116ms/step - accuracy: 0.8770 - loss: 0.2874 - val_accuracy: 0.8630 - val_loss: 0.3235 - learning_rate: 2.7000e-04
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 32.

# %%
def plot_learning_curves(history):
    acc = history.history["accuracy"]
    val_acc = history.history["val_accuracy"]
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    epochs_range = range(len(acc))


    plt.figure(figsize=(18, 7))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label="Training Accuracy")
    plt.plot(epochs_range, val_acc, label="Validation Accuracy")
    plt.legend()
    plt.title("Accuracy")

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label="Training Loss")
    plt.plot(epochs_range, val_loss, label="Validation Loss")
    plt.legend()
    plt.title("Loss")

    plt.show()

# %%
plot_learning_curves(history)

# %%
loss, accuracy = model.evaluate(validation_dataset)

print(f"Model Loss: {loss:.2f}")
print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.8654 - loss: 0.3076
# Model Loss: 0.31
# Model Accuracy: 0.87
